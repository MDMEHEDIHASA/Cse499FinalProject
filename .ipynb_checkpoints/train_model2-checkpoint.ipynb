# %%
import os
import cv2
import numpy as np
from imutils import paths

# %%
from matplotlib.image import imread

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
datapath = r"C:\Users\Asus\Desktop\data"
outputModel = './Video_Classfication_Model/videoClassificationModel'
outputLabelBinarizer = './model/VideoClassificationBinarizer'

# %%
pathToImages = list(paths.list_images(datapath+'\\train\\'))
pathToImages
# Out:
# ['C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000000.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000001.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000002.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000003.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000005.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000006.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000007.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000008.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000009.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000010.png',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000011.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000012.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000013.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000014.jpg',
# ...

# %%
test_path = datapath+'\\test\\'
train_path = datapath+'\\train\\'

# %%
firstImg = pathToImages

# %%
firstImg
# Out:
# ['C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000000.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000001.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000002.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000003.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000005.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000006.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000007.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000008.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000009.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000010.png',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000011.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000012.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000013.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000014.jpg',
# ...

# %%
firstImg[0]
# Out:
# 'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000000.jpg'

# %%
directory = firstImg[0]

# %%
directory
# Out:
# 'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000000.jpg'

# %%
firstImg[-1]
# Out:
# 'C:\\Users\\Asus\\Desktop\\data\\train\\violence\\V_996.mp4_frame0.jpg'

# %%
label = directory.split(os.path.sep)[-2]

# %%
label
# Out:
# 'swimming'

# %%
test_path
# Out:
# 'C:\\Users\\Asus\\Desktop\\data\\test\\'

# %%
os.listdir(test_path)
# Out:
# ['swimming', 'table_tennis', 'violence']

# %%
os.listdir(train_path)
# Out:
# ['swimming', 'table_tennis', 'violence']

# %%
os.listdir(train_path+'swimming')[0]
# Out:
# '00000000.jpg'

# %%
swimming_pic = train_path+'swimming\\'+'00000000.jpg'

# %%
imread(swimming_pic).shape
# Out:
# (333, 500, 3)

# %%
dim1 = []
dim2 = []

for image_filename in os.listdir(test_path+'table_tennis'):
    img  = imread(test_path+'table_tennis\\'+image_filename)
    d1,d2 = img.shape[:2]
    dim1.append(d1)
    dim2.append(d2)

# %%
import seaborn as sns

# %%
sns.jointplot(x=dim1,y=dim2)

# %%
np.mean(dim1)
# Out:
# 377.9583333333333

# %%
np.mean(dim2)
# Out:
# 509.3333333333333

# %%
firstImg = pathToImages[0]

# %%
print(firstImg)
# Out:
# C:\Users\Asus\Desktop\data\test\swimming\UA883XJNJ8GQ.jpg

# %%
pathToImages = list(paths.list_images(train_path))

# %%
pathToImages
# Out:
# ['C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000000.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000001.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000002.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000003.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000005.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000006.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000007.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000008.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000009.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000010.png',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000011.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000012.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000013.jpg',
#  'C:\\Users\\Asus\\Desktop\\data\\train\\swimming\\00000014.jpg',
# ...

# %%
label = directory.split(os.path.sep)[-2]

# %%
label
# Out:
# 'swimming'

# %%
for images in pathToImages:
    print(images)
# Out:
# C:\Users\Asus\Desktop\data\train\swimming\00000000.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000001.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000002.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000003.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000005.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000006.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000007.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000008.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000009.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000010.png
# C:\Users\Asus\Desktop\data\train\swimming\00000011.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000012.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000013.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000014.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000015.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000017.jpg
# C:\Users\Asus\Desktop\data\train\swimming\00000018.jpg
# ...

# %% [markdown]
# # My Creation anything

# %%
print("Images is being loaded.....")
pathToImages = list(paths.list_images(train_path))
data = []
labels = []
for images in pathToImages:
    label = images.split(os.path.sep)[-2]
    image = cv2.imread(images)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    image = cv2.resize(image,(244,244))
    data.append(image)
    labels.append(label)
# Out:
# Images is being loaded.....

# %%
labels
# Out:
# ['swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
#  'swimming',
# ...

# %%
data
# Out:
# [array([[[125, 179, 179],
#          [110, 164, 164],
#          [109, 163, 163],
#          ...,
#          [132, 179, 185],
#          [107, 151, 157],
#          [ 62, 107, 112]],
#
#         [[116, 170, 170],
#          [108, 162, 162],
#          [111, 165, 165],
#          ...,
#          [107, 151, 158],
#          [ 67, 107, 114],
#          [ 49,  89,  96]],
#
#         [[109, 163, 163],
#          [107, 161, 161],
#          [113, 167, 167],
#          ...,
#          [ 68, 108, 116],
#          [ 57,  91, 100],
#          [ 55,  89,  97]],
#
#         ...,
#
#         [[ 10, 165, 183],
#          [  9, 168, 184],
#          [  1, 162, 176],
#          ...,
#          [ 79, 171, 184],
#          [ 83, 174, 189],
#          [ 78, 170, 185]],
#
#         [[  8, 161, 179],
#          [  8, 163, 179],
#          [  4, 160, 175],
#          ...,
#          [ 75, 166, 179],
#          [ 81, 170, 184],
#          [ 82, 171, 185]],
#
#         [[  5, 156, 174],
# ...

# %%
#testing creation

Sports_lebel = set(['violence','swimming','table_tennis'])
print("Images is being loaded.....")
pathToImages = list(paths.list_images(datapath))
data = []
labels = []
for images in pathToImages:
    label = images.split(os.path.sep)[-2]
    if label not in Sports_lebel:
        continue
    image = cv2.imread(images)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    image = cv2.resize(image,(244,244))
    data.append(image)
    labels.append(label)
# Out:
# Images is being loaded.....

# %%
#labels
#data

# %%
data = np.array(data)
labels = np.array(labels)

# %%
labels
# Out:
# array(['swimming', 'swimming', 'swimming', ..., 'violence', 'violence',
#        'violence'], dtype='<U12')

# %%
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
trainingAugmentation  = ImageDataGenerator(
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest'
    
)

validationAugmentation = ImageDataGenerator()
mean = np.array([123.68,116.779,103.939],dtype="float32")
trainingAugmentation.mean = mean
validationAugmentation.mean = mean

# %%
from keras.layers import Input
from keras.layers.pooling import AveragePooling2D
from keras.applications.resnet import ResNet50
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers.core import Dropout
from keras.models import Model

# %%
baseModel = ResNet50(weights="imagenet",include_top=False,input_tensor=Input(shape=(224,224,3)))
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7,7))(headModel)
headModel = Flatten(name='flatten')(headModel)
headModel = Dense(512,activation='relu')(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(len(lb.classes_),activation='softmax')(headModel)
model = Model(inputs=baseModel.input,outputs=headModel)
for baseModelLayers in baseModel.layers:
    baseModelLayers.trainable = False

# %%
from tensorflow.keras.optimizers import SGD

# %%
epoch=25

# %%
opt = SGD(learning_rate=0.0001,momentum=0.9,decay=1e-4/epoch)

# %%
model.compile(loss="categorical_crossentropy",optimizer=opt,metrics=["accuracy"])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=2)

# %%
History = model.fit(
    trainingAugmentation.flow(X_train,y_train,batch_size=32),
    steps_per_epoch=len(X_train)//32,
    validation_data=validationAugmentation.flow(X_test,y_test),
    validation_steps=len(X_test)//32,
    epochs=epoch,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/25
# 185/185 [==============================] - 1319s 7s/step - loss: 0.5469 - accuracy: 0.8154 - val_loss: 0.2315 - val_accuracy: 0.9052
# Epoch 2/25
# 185/185 [==============================] - 1472s 8s/step - loss: 0.2805 - accuracy: 0.8987 - val_loss: 0.1581 - val_accuracy: 0.9395
# Epoch 3/25
# 185/185 [==============================] - 1479s 8s/step - loss: 0.2196 - accuracy: 0.9205 - val_loss: 0.1290 - val_accuracy: 0.9467
# Epoch 4/25
# 185/185 [==============================] - 1351s 7s/step - loss: 0.1932 - accuracy: 0.9308 - val_loss: 0.1075 - val_accuracy: 0.9590
# Epoch 5/25
# 185/185 [==============================] - 2050s 11s/step - loss: 0.1733 - accuracy: 0.9374 - val_loss: 0.0959 - val_accuracy: 0.9672
# Epoch 6/25
# 185/185 [==============================] - 1633s 9s/step - loss: 0.1559 - accuracy: 0.9464 - val_loss: 0.0882 - val_accuracy: 0.9682
# Epoch 7/25
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
pd.DataFrame(model.history.history)
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.546901  0.815429  0.231455      0.905225
# 1   0.280508  0.898664  0.158077      0.939549
# 2   0.219591  0.920487  0.129023      0.946721
# 3   0.193207  0.930807  0.107513      0.959016
# 4   0.173257  0.937405  0.095886      0.967213
# 5   0.155926  0.946371  0.088231      0.968238
# 6   0.151841  0.948232  0.082890      0.970287
# 7   0.138691  0.951108  0.081170      0.970799
# 8   0.136817  0.952292  0.074735      0.975410
# 9   0.122611  0.953984  0.070446      0.977459
# 10  0.120064  0.956183  0.068449      0.977459
# 11  0.118937  0.958552  0.066881      0.977459
# 12  0.118467  0.959736  0.063146      0.979508
# 13  0.107259  0.963627  0.063625      0.976947
# 14  0.113236  0.960074  0.063160      0.977459

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses[['loss','val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
losses[['accuracy','val_accuracy']].plot()
# Out:
# <AxesSubplot:>

# %%
import pickle

# %%
model.save('threechecks.h5')

# %%
model.save(outputModel)
lbinarizer = open('./model/VideoClassificationBinarizer.pickle','wb')
lbinarizer.write(pickle.dumps(lb))
lbinarizer.close()
# Out:
# INFO:tensorflow:Assets written to: ./Video_Classfication_Model/videoClassificationModel\assets
